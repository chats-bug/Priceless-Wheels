# %%
# Laad the transformed data
# Apply feature transformation to the data
# Write preprocessing pipelines and train the models
# Compare the performance of the models and select the best one

# %% [markdown]
# # Load the data
# In this step we will be loading our data and splitting it into training and test sets. We will also be loading the data into a pandas dataframe.

# %%
import os.path

from src.utils.data_loader import DataLoader
from src.feature_engineering.feature_transformations import FeatureEngineeringTransformations
import pandas as pd
import numpy as np

from src.utils.constants import INDEX, TARGET, PROCESSED_FILE_BEGIN

# %%
# Get the file path
processed_dir = '../data/processed'
dl = DataLoader(dir_path=processed_dir)
file_name = dl.get_latest_file(begins_with=PROCESSED_FILE_BEGIN)
filepath = os.path.join(processed_dir, file_name)

# %%
df = pd.read_csv(filepath, index_col=INDEX)
df.head()
# Out:
#                                       myear       body transmission fuel  \
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800   2016  hatchback       manual  cng
# c309efc1-efaf-4f82-81ad-dcb38eb36665   2015  hatchback       manual  cng
# 7609f710-0c97-4f00-9a47-9b9284b62d3a   2015      sedan       manual  cng
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d   2013  hatchback       manual  cng
# b1eab99b-a606-48dd-a75b-57feb8a9ad92   2022        muv       manual  cng
#
#                                       km_driven  ip     oem           model  \
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800      69162   0  maruti  maruti wagon r
# c309efc1-efaf-4f82-81ad-dcb38eb36665      45864   0  maruti  maruti celerio
# 7609f710-0c97-4f00-9a47-9b9284b62d3a      81506   0   honda     honda amaze
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d     115893   0  maruti  maruti wagon r
# b1eab99b-a606-48dd-a75b-57feb8a9ad92      18900   0  maruti   maruti ertiga
#
#                                             variant       City  ...  \
# usedCarSkuId                                                    ...
# 7111bf25-97af-47f9-867b-40879190d800        lxi cng    lucknow  ...
# c309efc1-efaf-4f82-81ad-dcb38eb36665      green vxi     mumbai  ...
# 7609f710-0c97-4f00-9a47-9b9284b62d3a  s plus i-vtec  new delhi  ...
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d        lxi cng  new delhi  ...
# b1eab99b-a606-48dd-a75b-57feb8a9ad92        vxi cng     mumbai  ...
#
#                                       Cargo Volume          state mileage_new  \
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800    180-liters  uttar pradesh       26.60
# c309efc1-efaf-4f82-81ad-dcb38eb36665    235-litres    maharashtra       31.79
# 7609f710-0c97-4f00-9a47-9b9284b62d3a    400-litres          delhi       18.00
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d           NaN          delhi       26.20
# b1eab99b-a606-48dd-a75b-57feb8a9ad92           NaN    maharashtra       26.11
#
#                                      owner_type           Fuel Suppy System  \
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800      first                         NaN
# c309efc1-efaf-4f82-81ad-dcb38eb36665      first     Gasoline Port Injection
# 7609f710-0c97-4f00-9a47-9b9284b62d3a     second                         NaN
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d     second  Multi-Point Fuel Injection
# b1eab99b-a606-48dd-a75b-57feb8a9ad92      first                         NaN
#
#                                      Alloy Wheel Size Max Power Delivered  \
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800              NaN               58.16
# c309efc1-efaf-4f82-81ad-dcb38eb36665              NaN               58.20
# 7609f710-0c97-4f00-9a47-9b9284b62d3a              NaN               86.70
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d             13.0               58.20
# b1eab99b-a606-48dd-a75b-57feb8a9ad92              NaN               86.63
#
#                                      Max Power At Max Torque Delivered  \
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800       6200.0                 77.0
# c309efc1-efaf-4f82-81ad-dcb38eb36665       6000.0                 78.0
# 7609f710-0c97-4f00-9a47-9b9284b62d3a       6000.0                109.0
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d       6200.0                 77.0
# b1eab99b-a606-48dd-a75b-57feb8a9ad92       5500.0                121.5
#
#                                       Max Torque At
# usedCarSkuId
# 7111bf25-97af-47f9-867b-40879190d800         3500.0
# c309efc1-efaf-4f82-81ad-dcb38eb36665         3500.0
# 7609f710-0c97-4f00-9a47-9b9284b62d3a         4500.0
# 278b76e3-5539-4a5e-ae3e-353a2e3b6d7d         3500.0
# b1eab99b-a606-48dd-a75b-57feb8a9ad92         4200.0
#
# [5 rows x 50 columns]

# %% [markdown]
# # Split the data into training and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
def generate_train_test_sets(df, target, test_size=0.2):
    """
    Generate the training and test sets from the data

    Parameters
    ---------
        df:
            The dataframe containing the data
        target:
            The target column
        test_size:
            The size of the test set

    Returns
    ---------
        X_train:
            The training set
        X_test:
            The test set
        y_train:
            The training target
        y_test:
            The test target
    """
    X = df.drop(target, axis=1)
    y = df[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = generate_train_test_sets(df, TARGET, test_size=0.3)

# Print the size of the training and test sets
print(f'The size of the training set is {X_train.shape[0]}')
print(f'The size of the test set is {X_test.shape[0]}')
# Out:
# The size of the training set is 26360
# The size of the test set is 11298

# %% [markdown]
# # Preprocessors and feature engineering

# %%
feat_eng = FeatureEngineeringTransformations()
train_combined = pd.concat([X_train, y_train], axis=1)
test_combined = pd.concat([X_test, y_test], axis=1)
train_combined = feat_eng.fit_transform(train_combined)
test_combined = feat_eng.transform(test_combined)

# Recover X_train, X_test, y_train, y_test
X_train = train_combined.drop(TARGET, axis=1)
y_train = train_combined[TARGET]
X_test = test_combined.drop(TARGET, axis=1)
y_test = test_combined[TARGET]

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from category_encoders import TargetEncoder
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.pipeline import Pipeline

# %%
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X_train.select_dtypes(include=['category', 'object', 'bool']).columns
# Convert all object and bool columns to category
X_train[categorical_cols] = X_train[categorical_cols].astype('category')
target_cols = ['oem', 'model', 'variant', 'City', 'state']
onehot_cols = [col for col in categorical_cols if col not in target_cols]
# Create a ColumnTransformer to apply different preprocessing to numerical and categorical columns
preprocessor1 = ColumnTransformer(transformers=[
	('num', StandardScaler(), numerical_cols),
	('cat', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), categorical_cols)
],
	remainder='passthrough'
)

preprocessor2 = ColumnTransformer(transformers=[
	('num', StandardScaler(), numerical_cols),
	('cat_onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), onehot_cols),
	('cat_target', TargetEncoder(), target_cols)
],
	remainder='passthrough'
)

numerical_transformer = Pipeline(steps=[
	('imputer', KNNImputer(n_neighbors=5)),
	('scaler', StandardScaler())
])

categorical_transformer_onehot = Pipeline(steps=[
	('imputer', SimpleImputer(strategy='most_frequent')),
	('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])

categorical_transformer_target = Pipeline(steps=[
	('imputer', SimpleImputer(strategy='most_frequent')),
	('target', TargetEncoder())
])

preprocessor3 = ColumnTransformer(transformers=[
	('num', numerical_transformer, numerical_cols),
	('cat_onehot', categorical_transformer_onehot, categorical_cols),
],
	remainder='passthrough'
)

preprocessor4 = ColumnTransformer(transformers=[
	('num', numerical_transformer, numerical_cols),
	('cat_onehot', categorical_transformer_onehot, onehot_cols),
	('cat_target', categorical_transformer_target, target_cols)
],
	remainder='passthrough'
)

# %% [markdown]
# # Models

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import cross_val_score, cross_validate

# %%
import lightgbm
import xgboost
import catboost
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.svm import SVR

# %%
def get_pipeline(model, preprocessor):
    pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('model', model)
    ])
    return pipe

def evaluate_model(model, X, y, cv=5):
    y_pred = model.predict(X)
    mape = mean_absolute_percentage_error(y, y_pred)
    mae = np.mean(np.abs(y - y_pred))
    scores = {
        'mape': mape,
        'mae': mae
    }
    return scores

# %% [markdown]
# ## CatBoost

# %%
cb_model = catboost.CatBoostRegressor(
	learning_rate = 0.1,
	depth = 6,
	l2_leaf_reg = 3,
	loss_function = 'MAE',
	bootstrap_type = 'Bernoulli',
	subsample = 0.7,
	od_type = 'Iter',
	od_wait = 50,
	random_seed = 42,
	allow_writing_files = False,
	verbose = 2,
	n_estimators = 1000,
)

# %%
X_train_cat = X_train.copy()
X_test_cat = X_test.copy()
y_train_cat = y_train.copy()
y_test_cat = y_test.copy()

# %%
cat_categorical_cols = X_train_cat.select_dtypes(include=['category', 'object']).columns
categorical_cols_with_nan = [col for col in cat_categorical_cols if X_train_cat[col].isnull().any()]
X_train_cat[categorical_cols] = X_train_cat[cat_categorical_cols].astype('category')
X_train_cat[categorical_cols] = X_train_cat[cat_categorical_cols].astype('category')

si = SimpleImputer(strategy='most_frequent', fill_value='missing')
X_train_cat[categorical_cols_with_nan] = si.fit_transform(X_train_cat[categorical_cols_with_nan])
X_test_cat[categorical_cols_with_nan] = si.transform(X_test_cat[categorical_cols_with_nan])

pool_train = catboost.Pool(X_train_cat, y_train_cat, cat_features=cat_categorical_cols.to_list())
pool_test = catboost.Pool(X_test_cat, cat_features=cat_categorical_cols.to_list())

# %%
cb_pipe_1 = get_pipeline(cb_model,ColumnTransformer(transformers=[
	('num', numerical_transformer, numerical_cols),
],
	remainder='passthrough'
))
cb_model.fit(pool_train)
# Out:
# 0:	learn: 435085.8527566	total: 55.3ms	remaining: 55.2s
# 2:	learn: 385412.0323704	total: 151ms	remaining: 50.2s
# 4:	learn: 348235.7977525	total: 243ms	remaining: 48.4s
# 6:	learn: 315386.2905680	total: 341ms	remaining: 48.4s
# 8:	learn: 288436.5924730	total: 433ms	remaining: 47.7s
# 10:	learn: 269309.7087129	total: 512ms	remaining: 46s
# 12:	learn: 248585.3010941	total: 594ms	remaining: 45.1s
# 14:	learn: 232504.6426143	total: 701ms	remaining: 46s
# 16:	learn: 217226.5676838	total: 796ms	remaining: 46s
# 18:	learn: 206964.2405824	total: 895ms	remaining: 46.2s
# 20:	learn: 197086.5316493	total: 990ms	remaining: 46.1s
# 22:	learn: 188596.3701482	total: 1.1s	remaining: 46.6s
# 24:	learn: 181470.6250960	total: 1.18s	remaining: 46s
# 26:	learn: 176390.4332900	total: 1.25s	remaining: 45.1s
# 28:	learn: 171017.2278428	total: 1.33s	remaining: 44.6s
# 30:	learn: 166045.1766631	total: 1.4s	remaining: 43.8s
# 32:	learn: 158936.9135287	total: 1.48s	remaining: 43.3s
# 34:	learn: 154792.8974132	total: 1.55s	remaining: 42.9s
# 36:	learn: 150215.8097244	total: 1.63s	remaining: 42.5s
# 38:	learn: 147275.4814414	total: 1.71s	remaining: 42.1s
# 40:	learn: 143704.4996975	total: 1.78s	remaining: 41.7s
# 42:	learn: 139845.9290676	total: 1.85s	remaining: 41.3s
# 44:	learn: 136826.5850821	total: 1.93s	remaining: 40.9s
# 46:	learn: 133572.5801701	total: 2s	remaining: 40.6s
# 48:	learn: 130994.5248326	total: 2.08s	remaining: 40.4s
# 50:	learn: 128645.7130987	total: 2.15s	remaining: 40.1s
# 52:	learn: 127702.8244771	total: 2.22s	remaining: 39.7s
# 54:	learn: 126521.8206345	total: 2.3s	remaining: 39.5s
# 56:	learn: 124763.6699232	total: 2.37s	remaining: 39.3s
# 58:	learn: 123145.2066854	total: 2.45s	remaining: 39.1s
# 60:	learn: 122260.5608416	total: 2.53s	remaining: 38.9s
# 62:	learn: 120847.4603684	total: 2.6s	remaining: 38.7s
# 64:	learn: 119348.3618113	total: 2.67s	remaining: 38.3s
# 66:	learn: 118633.6397419	total: 2.74s	remaining: 38.2s
# 68:	learn: 117572.6163025	total: 2.81s	remaining: 37.9s
# 70:	learn: 116526.4688005	total: 2.88s	remaining: 37.7s
# 72:	learn: 115457.8268435	total: 2.95s	remaining: 37.4s
# 74:	learn: 114757.9936836	total: 3.02s	remaining: 37.2s
# 76:	learn: 113610.4908250	total: 3.09s	remaining: 37s
# 78:	learn: 112706.3429947	total: 3.16s	remaining: 36.9s
# 80:	learn: 111830.4045324	total: 3.23s	remaining: 36.7s
# 82:	learn: 111169.7968721	total: 3.31s	remaining: 36.5s
# 84:	learn: 110124.9170974	total: 3.38s	remaining: 36.3s
# 86:	learn: 109000.1507110	total: 3.44s	remaining: 36.1s
# 88:	learn: 108433.0911708	total: 3.52s	remaining: 36s
# 90:	learn: 108026.6072956	total: 3.6s	remaining: 35.9s
# 92:	learn: 107273.5808503	total: 3.66s	remaining: 35.7s
# 94:	learn: 106546.8360708	total: 3.72s	remaining: 35.5s
# 96:	learn: 105783.3703082	total: 3.8s	remaining: 35.4s
# 98:	learn: 105119.0376908	total: 3.87s	remaining: 35.2s
# 100:	learn: 104261.4895168	total: 3.93s	remaining: 35s
# 102:	learn: 103933.6659684	total: 4.01s	remaining: 34.9s
# 104:	learn: 103173.7663145	total: 4.08s	remaining: 34.8s
# 106:	learn: 102348.5458111	total: 4.14s	remaining: 34.6s
# 108:	learn: 101957.3905404	total: 4.21s	remaining: 34.5s
# 110:	learn: 101591.9473877	total: 4.28s	remaining: 34.3s
# 112:	learn: 101253.5853761	total: 4.35s	remaining: 34.1s
# 114:	learn: 100936.3641663	total: 4.43s	remaining: 34.1s
# 116:	learn: 100446.5805254	total: 4.51s	remaining: 34s
# 118:	learn: 100045.4069450	total: 4.58s	remaining: 33.9s
# 120:	learn: 99783.9018791	total: 4.67s	remaining: 33.9s
# 122:	learn: 99462.3369220	total: 4.74s	remaining: 33.8s
# 124:	learn: 98993.2019181	total: 4.82s	remaining: 33.7s
# 126:	learn: 98766.4561770	total: 4.9s	remaining: 33.7s
# 128:	learn: 98660.3804577	total: 4.98s	remaining: 33.6s
# 130:	learn: 98007.7766571	total: 5.06s	remaining: 33.6s
# 132:	learn: 97807.0763077	total: 5.13s	remaining: 33.5s
# 134:	learn: 97589.8318960	total: 5.2s	remaining: 33.3s
# 136:	learn: 97097.9572122	total: 5.26s	remaining: 33.2s
# 138:	learn: 96595.6930247	total: 5.34s	remaining: 33.1s
# 140:	learn: 96450.2184751	total: 5.41s	remaining: 33s
# 142:	learn: 95882.2893189	total: 5.48s	remaining: 32.9s
# 144:	learn: 95736.4948025	total: 5.55s	remaining: 32.7s
# 146:	learn: 95478.7835596	total: 5.63s	remaining: 32.7s
# 148:	learn: 95247.6956415	total: 5.7s	remaining: 32.6s
# 150:	learn: 94799.5518431	total: 5.77s	remaining: 32.5s
# 152:	learn: 94560.0614020	total: 5.85s	remaining: 32.4s
# 154:	learn: 94275.3687254	total: 5.92s	remaining: 32.2s
# 156:	learn: 94152.0304774	total: 5.99s	remaining: 32.1s
# 158:	learn: 93827.8401138	total: 6.05s	remaining: 32s
# 160:	learn: 93693.1732453	total: 6.12s	remaining: 31.9s
# 162:	learn: 93252.6380900	total: 6.2s	remaining: 31.8s
# 164:	learn: 92987.2608655	total: 6.27s	remaining: 31.8s
# 166:	learn: 92694.7063898	total: 6.34s	remaining: 31.6s
# 168:	learn: 92212.2497612	total: 6.42s	remaining: 31.6s
# 170:	learn: 91868.7671011	total: 6.51s	remaining: 31.6s
# 172:	learn: 91707.5712339	total: 6.6s	remaining: 31.6s
# 174:	learn: 91452.2717966	total: 6.69s	remaining: 31.5s
# 176:	learn: 91355.4301501	total: 6.76s	remaining: 31.5s
# 178:	learn: 90849.9989289	total: 6.84s	remaining: 31.4s
# 180:	learn: 90429.9490719	total: 6.92s	remaining: 31.3s
# 182:	learn: 90244.0254163	total: 7s	remaining: 31.3s
# 184:	learn: 90190.1358744	total: 7.08s	remaining: 31.2s
# 186:	learn: 90015.1833008	total: 7.16s	remaining: 31.1s
# 188:	learn: 89785.7387136	total: 7.25s	remaining: 31.1s
# 190:	learn: 89433.0095670	total: 7.32s	remaining: 31s
# 192:	learn: 89305.9381950	total: 7.41s	remaining: 31s
# 194:	learn: 88825.3220105	total: 7.49s	remaining: 30.9s
# 196:	learn: 88430.1119073	total: 7.57s	remaining: 30.9s
# 198:	learn: 88092.5959070	total: 7.64s	remaining: 30.8s
# 200:	learn: 87888.6446591	total: 7.72s	remaining: 30.7s
# 202:	learn: 87395.8464767	total: 7.79s	remaining: 30.6s
# 204:	learn: 87282.8904111	total: 7.88s	remaining: 30.6s
# 206:	learn: 87059.1569506	total: 7.96s	remaining: 30.5s
# 208:	learn: 87007.5032875	total: 8.06s	remaining: 30.5s
# 210:	learn: 86717.5744443	total: 8.14s	remaining: 30.5s
# 212:	learn: 86626.2772962	total: 8.22s	remaining: 30.4s
# 214:	learn: 86128.0230335	total: 8.3s	remaining: 30.3s
# 216:	learn: 86021.7219398	total: 8.38s	remaining: 30.2s
# 218:	learn: 85809.8365024	total: 8.46s	remaining: 30.2s
# 220:	learn: 85527.8095095	total: 8.53s	remaining: 30.1s
# 222:	learn: 85470.2156833	total: 8.61s	remaining: 30s
# 224:	learn: 85297.5815366	total: 8.68s	remaining: 29.9s
# 226:	learn: 84994.1917282	total: 8.76s	remaining: 29.8s
# 228:	learn: 84864.8714804	total: 8.84s	remaining: 29.8s
# 230:	learn: 84696.0666301	total: 8.91s	remaining: 29.7s
# 232:	learn: 84605.0446029	total: 9s	remaining: 29.6s
# 234:	learn: 84368.1088223	total: 9.07s	remaining: 29.5s
# 236:	learn: 84314.4517157	total: 9.15s	remaining: 29.5s
# 238:	learn: 84029.5323143	total: 9.23s	remaining: 29.4s
# 240:	learn: 83768.6399431	total: 9.31s	remaining: 29.3s
# 242:	learn: 83689.8189160	total: 9.37s	remaining: 29.2s
# 244:	learn: 83537.7756786	total: 9.43s	remaining: 29.1s
# 246:	learn: 83484.0890029	total: 9.51s	remaining: 29s
# 248:	learn: 83372.7100531	total: 9.58s	remaining: 28.9s
# 250:	learn: 83287.8785089	total: 9.65s	remaining: 28.8s
# 252:	learn: 83134.2037508	total: 9.72s	remaining: 28.7s
# 254:	learn: 83086.6062838	total: 9.79s	remaining: 28.6s
# 256:	learn: 83045.3324378	total: 9.86s	remaining: 28.5s
# 258:	learn: 82815.2795358	total: 9.93s	remaining: 28.4s
# 260:	learn: 82769.5607975	total: 10s	remaining: 28.3s
# 262:	learn: 82560.7232046	total: 10.1s	remaining: 28.2s
# 264:	learn: 82452.1573552	total: 10.1s	remaining: 28.1s
# 266:	learn: 82233.6153200	total: 10.2s	remaining: 28s
# 268:	learn: 82068.5035574	total: 10.3s	remaining: 28s
# 270:	learn: 81980.0676674	total: 10.4s	remaining: 27.9s
# 272:	learn: 81878.5481504	total: 10.4s	remaining: 27.8s
# 274:	learn: 81582.5535312	total: 10.5s	remaining: 27.7s
# 276:	learn: 81510.5863785	total: 10.6s	remaining: 27.6s
# 278:	learn: 81366.7115767	total: 10.7s	remaining: 27.6s
# 280:	learn: 81298.3528478	total: 10.8s	remaining: 27.5s
# 282:	learn: 81192.5625698	total: 10.8s	remaining: 27.4s
# 284:	learn: 81152.6487145	total: 10.9s	remaining: 27.4s
# 286:	learn: 80991.5835512	total: 11s	remaining: 27.3s
# 288:	learn: 80866.2160402	total: 11s	remaining: 27.2s
# 290:	learn: 80787.1613175	total: 11.1s	remaining: 27.1s
# 292:	learn: 80754.0553990	total: 11.2s	remaining: 27s
# 294:	learn: 80727.0922051	total: 11.2s	remaining: 26.9s
# 296:	learn: 80597.8422324	total: 11.3s	remaining: 26.8s
# 298:	learn: 80476.4895469	total: 11.4s	remaining: 26.7s
# 300:	learn: 80392.2077050	total: 11.5s	remaining: 26.6s
# 302:	learn: 80338.8974497	total: 11.5s	remaining: 26.5s
# 304:	learn: 80230.4357937	total: 11.6s	remaining: 26.4s
# 306:	learn: 80205.8109723	total: 11.7s	remaining: 26.3s
# 308:	learn: 80132.8541444	total: 11.7s	remaining: 26.3s
# 310:	learn: 80034.3599024	total: 11.8s	remaining: 26.1s
# 312:	learn: 79975.5029002	total: 11.9s	remaining: 26.1s
# 314:	learn: 79808.5363434	total: 11.9s	remaining: 26s
# 316:	learn: 79671.9339925	total: 12s	remaining: 25.9s
# 318:	learn: 79520.2730946	total: 12.1s	remaining: 25.8s
# 320:	learn: 79456.3444831	total: 12.2s	remaining: 25.7s
# 322:	learn: 79204.2374075	total: 12.2s	remaining: 25.6s
# 324:	learn: 79077.7402872	total: 12.3s	remaining: 25.6s
# 326:	learn: 79046.7690038	total: 12.4s	remaining: 25.5s
# 328:	learn: 78995.5233844	total: 12.4s	remaining: 25.4s
# 330:	learn: 78930.5256406	total: 12.5s	remaining: 25.3s
# 332:	learn: 78798.1307244	total: 12.6s	remaining: 25.2s
# 334:	learn: 78753.8382789	total: 12.7s	remaining: 25.1s
# 336:	learn: 78698.8717638	total: 12.7s	remaining: 25.1s
# 338:	learn: 78520.4338687	total: 12.8s	remaining: 25s
# 340:	learn: 78350.9791354	total: 12.9s	remaining: 24.9s
# 342:	learn: 78168.9142905	total: 13s	remaining: 24.8s
# 344:	learn: 78074.3192747	total: 13s	remaining: 24.7s
# 346:	learn: 77850.7170664	total: 13.1s	remaining: 24.7s
# 348:	learn: 77670.9376123	total: 13.2s	remaining: 24.6s
# 350:	learn: 77603.1305606	total: 13.3s	remaining: 24.5s
# 352:	learn: 77375.1457976	total: 13.3s	remaining: 24.4s
# 354:	learn: 77207.9371154	total: 13.4s	remaining: 24.3s
# 356:	learn: 77173.2628712	total: 13.5s	remaining: 24.3s
# 358:	learn: 77091.0617910	total: 13.5s	remaining: 24.2s
# 360:	learn: 77039.3834516	total: 13.6s	remaining: 24.1s
# 362:	learn: 76977.9248686	total: 13.7s	remaining: 24s
# 364:	learn: 76858.3238957	total: 13.8s	remaining: 23.9s
# 366:	learn: 76760.8078441	total: 13.8s	remaining: 23.8s
# 368:	learn: 76733.9160830	total: 13.9s	remaining: 23.8s
# 370:	learn: 76692.9244571	total: 14s	remaining: 23.8s
# 372:	learn: 76659.8994022	total: 14.1s	remaining: 23.7s
# 374:	learn: 76578.5949298	total: 14.2s	remaining: 23.6s
# 376:	learn: 76544.7013768	total: 14.3s	remaining: 23.6s
# 378:	learn: 76398.2431133	total: 14.3s	remaining: 23.5s
# 380:	learn: 76355.3992635	total: 14.4s	remaining: 23.4s
# 382:	learn: 76311.8754714	total: 14.5s	remaining: 23.4s
# 384:	learn: 76246.4454969	total: 14.6s	remaining: 23.3s
# 386:	learn: 76183.8577829	total: 14.7s	remaining: 23.2s
# 388:	learn: 76141.1781755	total: 14.7s	remaining: 23.2s
# 390:	learn: 76113.1668185	total: 14.8s	remaining: 23.1s
# 392:	learn: 75993.0290784	total: 14.9s	remaining: 23s
# 394:	learn: 75878.7628446	total: 15s	remaining: 22.9s
# 396:	learn: 75825.8207718	total: 15.1s	remaining: 22.9s
# 398:	learn: 75798.8065068	total: 15.2s	remaining: 22.8s
# 400:	learn: 75718.6578204	total: 15.2s	remaining: 22.8s
# 402:	learn: 75621.0746389	total: 15.3s	remaining: 22.7s
# 404:	learn: 75495.7726708	total: 15.4s	remaining: 22.6s
# 406:	learn: 75459.8715344	total: 15.5s	remaining: 22.6s
# 408:	learn: 75433.0157712	total: 15.6s	remaining: 22.5s
# 410:	learn: 75376.6023560	total: 15.6s	remaining: 22.4s
# 412:	learn: 75263.2320230	total: 15.7s	remaining: 22.4s
# 414:	learn: 75243.0544867	total: 15.8s	remaining: 22.3s
# 416:	learn: 75138.8600378	total: 15.9s	remaining: 22.2s
# 418:	learn: 75055.8132350	total: 16s	remaining: 22.2s
# 420:	learn: 74971.6466287	total: 16.1s	remaining: 22.2s
# 422:	learn: 74902.0819451	total: 16.2s	remaining: 22.1s
# 424:	learn: 74853.1680321	total: 16.3s	remaining: 22.1s
# 426:	learn: 74727.6018357	total: 16.4s	remaining: 22s
# 428:	learn: 74652.3132493	total: 16.5s	remaining: 21.9s
# 430:	learn: 74531.6221173	total: 16.5s	remaining: 21.8s
# 432:	learn: 74486.9036872	total: 16.6s	remaining: 21.8s
# 434:	learn: 74400.0864529	total: 16.7s	remaining: 21.7s
# 436:	learn: 74248.2983362	total: 16.8s	remaining: 21.6s
# 438:	learn: 74203.2541457	total: 16.9s	remaining: 21.5s
# 440:	learn: 74133.0737211	total: 16.9s	remaining: 21.5s
# 442:	learn: 74085.3082393	total: 17s	remaining: 21.4s
# 444:	learn: 73995.8684255	total: 17.1s	remaining: 21.3s
# 446:	learn: 73932.4345847	total: 17.2s	remaining: 21.3s
# 448:	learn: 73875.7414158	total: 17.3s	remaining: 21.2s
# 450:	learn: 73839.1911622	total: 17.3s	remaining: 21.1s
# 452:	learn: 73800.6191740	total: 17.4s	remaining: 21s
# 454:	learn: 73778.0551071	total: 17.5s	remaining: 20.9s
# 456:	learn: 73706.7710547	total: 17.6s	remaining: 20.9s
# 458:	learn: 73652.3430425	total: 17.6s	remaining: 20.8s
# 460:	learn: 73483.2451196	total: 17.7s	remaining: 20.7s
# 462:	learn: 73399.6965703	total: 17.8s	remaining: 20.6s
# 464:	learn: 73362.0265325	total: 17.8s	remaining: 20.5s
# 466:	learn: 73305.8992962	total: 17.9s	remaining: 20.4s
# 468:	learn: 73218.9128857	total: 18s	remaining: 20.4s
# 470:	learn: 73141.0742511	total: 18.1s	remaining: 20.3s
# 472:	learn: 73097.7430203	total: 18.1s	remaining: 20.2s
# 474:	learn: 72995.0480241	total: 18.2s	remaining: 20.1s
# 476:	learn: 72925.3474117	total: 18.3s	remaining: 20s
# 478:	learn: 72890.5418580	total: 18.3s	remaining: 20s
# 480:	learn: 72845.7461214	total: 18.4s	remaining: 19.9s
# 482:	learn: 72783.4721193	total: 18.5s	remaining: 19.8s
# 484:	learn: 72744.6060863	total: 18.6s	remaining: 19.7s
# 486:	learn: 72644.9337925	total: 18.6s	remaining: 19.6s
# 488:	learn: 72601.6594250	total: 18.7s	remaining: 19.6s
# 490:	learn: 72507.2794284	total: 18.8s	remaining: 19.5s
# 492:	learn: 72420.3161247	total: 18.9s	remaining: 19.4s
# 494:	learn: 72375.7446418	total: 18.9s	remaining: 19.3s
# 496:	learn: 72336.2313743	total: 19s	remaining: 19.3s
# 498:	learn: 72250.4121318	total: 19.1s	remaining: 19.2s
# 500:	learn: 72168.4704835	total: 19.2s	remaining: 19.1s
# 502:	learn: 72137.1568552	total: 19.3s	remaining: 19s
# 504:	learn: 72081.7419892	total: 19.3s	remaining: 18.9s
# 506:	learn: 72039.9569402	total: 19.4s	remaining: 18.9s
# 508:	learn: 71952.5879181	total: 19.5s	remaining: 18.8s
# 510:	learn: 71834.4169331	total: 19.6s	remaining: 18.7s
# 512:	learn: 71807.6681509	total: 19.6s	remaining: 18.6s
# 514:	learn: 71787.4613604	total: 19.7s	remaining: 18.6s
# 516:	learn: 71749.8593160	total: 19.8s	remaining: 18.5s
# 518:	learn: 71659.6630381	total: 19.9s	remaining: 18.4s
# 520:	learn: 71621.8511397	total: 19.9s	remaining: 18.3s
# 522:	learn: 71479.7167134	total: 20s	remaining: 18.3s
# 524:	learn: 71436.9070770	total: 20.1s	remaining: 18.2s
# 526:	learn: 71418.8658760	total: 20.2s	remaining: 18.1s
# 528:	learn: 71336.7331589	total: 20.3s	remaining: 18s
# 530:	learn: 71296.8526805	total: 20.3s	remaining: 17.9s
# 532:	learn: 71231.8743284	total: 20.4s	remaining: 17.9s
# 534:	learn: 71203.7175616	total: 20.5s	remaining: 17.8s
# 536:	learn: 71153.2199207	total: 20.6s	remaining: 17.7s
# 538:	learn: 71131.1875728	total: 20.6s	remaining: 17.6s
# 540:	learn: 71097.5015304	total: 20.7s	remaining: 17.6s
# 542:	learn: 71063.4288827	total: 20.8s	remaining: 17.5s
# 544:	learn: 71002.3375174	total: 20.9s	remaining: 17.4s
# 546:	learn: 70900.8968084	total: 20.9s	remaining: 17.3s
# 548:	learn: 70887.7538523	total: 21s	remaining: 17.3s
# 550:	learn: 70790.5143335	total: 21.1s	remaining: 17.2s
# 552:	learn: 70711.3125104	total: 21.2s	remaining: 17.1s
# 554:	learn: 70634.8823740	total: 21.3s	remaining: 17.1s
# 556:	learn: 70560.7233309	total: 21.3s	remaining: 17s
# 558:	learn: 70495.7024726	total: 21.4s	remaining: 16.9s
# 560:	learn: 70433.6891004	total: 21.5s	remaining: 16.8s
# 562:	learn: 70313.5734743	total: 21.6s	remaining: 16.7s
# 564:	learn: 70275.8414918	total: 21.6s	remaining: 16.7s
# 566:	learn: 70244.4407405	total: 21.7s	remaining: 16.6s
# 568:	learn: 70145.8153613	total: 21.8s	remaining: 16.5s
# 570:	learn: 70095.1092780	total: 21.9s	remaining: 16.4s
# 572:	learn: 70063.4753215	total: 21.9s	remaining: 16.4s
# 574:	learn: 70008.6011949	total: 22s	remaining: 16.3s
# 576:	learn: 69971.5830972	total: 22.1s	remaining: 16.2s
# 578:	learn: 69897.5286273	total: 22.2s	remaining: 16.1s
# 580:	learn: 69838.7186204	total: 22.3s	remaining: 16.1s
# 582:	learn: 69787.1733530	total: 22.4s	remaining: 16s
# 584:	learn: 69754.4521417	total: 22.5s	remaining: 15.9s
# 586:	learn: 69718.1748430	total: 22.6s	remaining: 15.9s
# 588:	learn: 69664.3653420	total: 22.7s	remaining: 15.8s
# 590:	learn: 69637.9182831	total: 22.8s	remaining: 15.8s
# 592:	learn: 69563.0135505	total: 22.9s	remaining: 15.7s
# 594:	learn: 69524.9123758	total: 23s	remaining: 15.6s
# 596:	learn: 69513.1373945	total: 23.1s	remaining: 15.6s
# 598:	learn: 69482.8123302	total: 23.2s	remaining: 15.5s
# 600:	learn: 69456.7757003	total: 23.3s	remaining: 15.4s
# 602:	learn: 69423.2083257	total: 23.4s	remaining: 15.4s
# 604:	learn: 69396.3233823	total: 23.4s	remaining: 15.3s
# 606:	learn: 69317.5453457	total: 23.5s	remaining: 15.2s
# 608:	learn: 69299.7825330	total: 23.6s	remaining: 15.2s
# 610:	learn: 69254.4622254	total: 23.7s	remaining: 15.1s
# 612:	learn: 69201.5646230	total: 23.8s	remaining: 15s
# 614:	learn: 69124.0836733	total: 23.9s	remaining: 15s
# 616:	learn: 69070.5770841	total: 24s	remaining: 14.9s
# 618:	learn: 69046.9774949	total: 24.1s	remaining: 14.9s
# 620:	learn: 68998.0093616	total: 24.2s	remaining: 14.8s
# 622:	learn: 68984.1884935	total: 24.3s	remaining: 14.7s
# 624:	learn: 68954.9336575	total: 24.4s	remaining: 14.7s
# 626:	learn: 68929.1081472	total: 24.5s	remaining: 14.6s
# 628:	learn: 68914.9891590	total: 24.6s	remaining: 14.5s
# 630:	learn: 68887.4345253	total: 24.7s	remaining: 14.5s
# 632:	learn: 68871.8309354	total: 24.8s	remaining: 14.4s
# 634:	learn: 68858.2196647	total: 24.9s	remaining: 14.3s
# 636:	learn: 68824.7524570	total: 25.1s	remaining: 14.3s
# 638:	learn: 68803.7123233	total: 25.2s	remaining: 14.2s
# 640:	learn: 68742.8986035	total: 25.3s	remaining: 14.1s
# 642:	learn: 68712.4652483	total: 25.3s	remaining: 14.1s
# 644:	learn: 68691.9145548	total: 25.4s	remaining: 14s
# 646:	learn: 68663.3514252	total: 25.5s	remaining: 13.9s
# 648:	learn: 68643.8426929	total: 25.6s	remaining: 13.8s
# 650:	learn: 68608.2514519	total: 25.7s	remaining: 13.8s
# 652:	learn: 68535.3284232	total: 25.8s	remaining: 13.7s
# 654:	learn: 68502.6515666	total: 25.9s	remaining: 13.6s
# 656:	learn: 68442.0814034	total: 25.9s	remaining: 13.5s
# 658:	learn: 68418.8403681	total: 26s	remaining: 13.5s
# 660:	learn: 68347.9902331	total: 26.1s	remaining: 13.4s
# 662:	learn: 68315.4920904	total: 26.2s	remaining: 13.3s
# 664:	learn: 68273.8553728	total: 26.3s	remaining: 13.2s
# 666:	learn: 68201.4143654	total: 26.3s	remaining: 13.2s
# 668:	learn: 68124.2495878	total: 26.4s	remaining: 13.1s
# 670:	learn: 68103.9896179	total: 26.5s	remaining: 13s
# 672:	learn: 68086.1794754	total: 26.6s	remaining: 12.9s
# 674:	learn: 67954.0451004	total: 26.7s	remaining: 12.9s
# 676:	learn: 67938.4246370	total: 26.8s	remaining: 12.8s
# 678:	learn: 67877.1893214	total: 26.9s	remaining: 12.7s
# 680:	learn: 67857.3272874	total: 27s	remaining: 12.6s
# 682:	learn: 67795.3284515	total: 27s	remaining: 12.6s
# 684:	learn: 67778.2054461	total: 27.1s	remaining: 12.5s
# 686:	learn: 67698.0696814	total: 27.2s	remaining: 12.4s
# 688:	learn: 67674.4296758	total: 27.3s	remaining: 12.3s
# 690:	learn: 67647.9613318	total: 27.4s	remaining: 12.2s
# 692:	learn: 67620.1626879	total: 27.5s	remaining: 12.2s
# 694:	learn: 67585.7887664	total: 27.5s	remaining: 12.1s
# 696:	learn: 67541.6902023	total: 27.6s	remaining: 12s
# 698:	learn: 67521.9778337	total: 27.7s	remaining: 11.9s
# 700:	learn: 67501.9970699	total: 27.8s	remaining: 11.9s
# 702:	learn: 67432.3293523	total: 27.9s	remaining: 11.8s
# 704:	learn: 67418.4092420	total: 28s	remaining: 11.7s
# 706:	learn: 67348.5125158	total: 28s	remaining: 11.6s
# 708:	learn: 67321.8967627	total: 28.1s	remaining: 11.5s
# 710:	learn: 67310.7307074	total: 28.2s	remaining: 11.5s
# 712:	learn: 67261.2348451	total: 28.3s	remaining: 11.4s
# 714:	learn: 67225.2668697	total: 28.4s	remaining: 11.3s
# 716:	learn: 67208.8580613	total: 28.5s	remaining: 11.2s
# 718:	learn: 67179.1743451	total: 28.5s	remaining: 11.2s
# 720:	learn: 67153.4098591	total: 28.6s	remaining: 11.1s
# 722:	learn: 67030.9190451	total: 28.7s	remaining: 11s
# 724:	learn: 66992.7182816	total: 28.8s	remaining: 10.9s
# 726:	learn: 66981.5307622	total: 28.9s	remaining: 10.8s
# 728:	learn: 66894.3392673	total: 29s	remaining: 10.8s
# 730:	learn: 66872.0591271	total: 29s	remaining: 10.7s
# 732:	learn: 66770.0760841	total: 29.1s	remaining: 10.6s
# 734:	learn: 66726.0971763	total: 29.2s	remaining: 10.5s
# 736:	learn: 66713.8815246	total: 29.3s	remaining: 10.4s
# 738:	learn: 66702.5607718	total: 29.4s	remaining: 10.4s
# 740:	learn: 66689.3791601	total: 29.4s	remaining: 10.3s
# 742:	learn: 66662.2961673	total: 29.5s	remaining: 10.2s
# 744:	learn: 66653.4107645	total: 29.6s	remaining: 10.1s
# 746:	learn: 66613.8698523	total: 29.7s	remaining: 10s
# 748:	learn: 66593.6719531	total: 29.8s	remaining: 9.97s
# 750:	learn: 66571.1022013	total: 29.8s	remaining: 9.89s
# 752:	learn: 66541.7888479	total: 29.9s	remaining: 9.81s
# 754:	learn: 66519.9513900	total: 30s	remaining: 9.73s
# 756:	learn: 66510.3791553	total: 30.1s	remaining: 9.65s
# 758:	learn: 66497.3031084	total: 30.2s	remaining: 9.58s
# 760:	learn: 66482.1036185	total: 30.3s	remaining: 9.5s
# 762:	learn: 66424.4047481	total: 30.3s	remaining: 9.42s
# 764:	learn: 66392.7032405	total: 30.4s	remaining: 9.34s
# 766:	learn: 66330.5447195	total: 30.5s	remaining: 9.26s
# 768:	learn: 66309.9391533	total: 30.6s	remaining: 9.18s
# 770:	learn: 66285.0570193	total: 30.6s	remaining: 9.1s
# 772:	learn: 66253.3350348	total: 30.7s	remaining: 9.02s
# 774:	learn: 66245.2023960	total: 30.8s	remaining: 8.94s
# 776:	learn: 66235.4274385	total: 30.9s	remaining: 8.86s
# 778:	learn: 66181.0977719	total: 31s	remaining: 8.79s
# 780:	learn: 66147.8737927	total: 31.1s	remaining: 8.71s
# 782:	learn: 66131.3681293	total: 31.2s	remaining: 8.64s
# 784:	learn: 66096.6861606	total: 31.3s	remaining: 8.56s
# 786:	learn: 66062.4168418	total: 31.4s	remaining: 8.49s
# 788:	learn: 66034.9450683	total: 31.4s	remaining: 8.41s
# 790:	learn: 66001.8873226	total: 31.5s	remaining: 8.33s
# 792:	learn: 65989.0588421	total: 31.6s	remaining: 8.25s
# 794:	learn: 65948.2836073	total: 31.7s	remaining: 8.18s
# 796:	learn: 65940.3613609	total: 31.8s	remaining: 8.1s
# 798:	learn: 65908.9119911	total: 31.9s	remaining: 8.02s
# 800:	learn: 65844.2338198	total: 32s	remaining: 7.95s
# 802:	learn: 65818.3577429	total: 32.1s	remaining: 7.87s
# 804:	learn: 65808.0190178	total: 32.1s	remaining: 7.79s
# 806:	learn: 65790.5954115	total: 32.2s	remaining: 7.71s
# 808:	learn: 65763.8110783	total: 32.3s	remaining: 7.63s
# 810:	learn: 65709.8390119	total: 32.4s	remaining: 7.56s
# 812:	learn: 65671.5762944	total: 32.5s	remaining: 7.48s
# 814:	learn: 65641.5318862	total: 32.6s	remaining: 7.4s
# 816:	learn: 65605.4935993	total: 32.7s	remaining: 7.33s
# 818:	learn: 65568.4720886	total: 32.8s	remaining: 7.25s
# 820:	learn: 65531.4176144	total: 32.9s	remaining: 7.17s
# 822:	learn: 65520.4009563	total: 33s	remaining: 7.09s
# 824:	learn: 65511.5378713	total: 33s	remaining: 7.01s
# 826:	learn: 65493.3963864	total: 33.1s	remaining: 6.93s
# 828:	learn: 65479.0614139	total: 33.2s	remaining: 6.85s
# 830:	learn: 65460.1740706	total: 33.3s	remaining: 6.77s
# 832:	learn: 65445.2624276	total: 33.4s	remaining: 6.69s
# 834:	learn: 65406.1570363	total: 33.5s	remaining: 6.62s
# 836:	learn: 65377.1683971	total: 33.6s	remaining: 6.54s
# 838:	learn: 65353.5639275	total: 33.7s	remaining: 6.46s
# 840:	learn: 65342.7887076	total: 33.8s	remaining: 6.38s
# 842:	learn: 65330.5099925	total: 33.9s	remaining: 6.31s
# 844:	learn: 65289.0108635	total: 33.9s	remaining: 6.23s
# 846:	learn: 65258.7974876	total: 34s	remaining: 6.15s
# 848:	learn: 65234.2476359	total: 34.1s	remaining: 6.07s
# 850:	learn: 65220.4547825	total: 34.2s	remaining: 5.99s
# 852:	learn: 65207.0577023	total: 34.3s	remaining: 5.91s
# 854:	learn: 65197.9188091	total: 34.4s	remaining: 5.83s
# 856:	learn: 65173.9344509	total: 34.5s	remaining: 5.75s
# 858:	learn: 65136.3126335	total: 34.5s	remaining: 5.67s
# 860:	learn: 65107.1680409	total: 34.6s	remaining: 5.59s
# 862:	learn: 65050.0065692	total: 34.7s	remaining: 5.51s
# 864:	learn: 64995.7283900	total: 34.8s	remaining: 5.43s
# 866:	learn: 64961.7564181	total: 34.9s	remaining: 5.35s
# 868:	learn: 64937.3227966	total: 34.9s	remaining: 5.27s
# 870:	learn: 64892.4802338	total: 35s	remaining: 5.19s
# 872:	learn: 64867.2608410	total: 35.1s	remaining: 5.11s
# 874:	learn: 64861.5726367	total: 35.2s	remaining: 5.03s
# 876:	learn: 64849.8435174	total: 35.3s	remaining: 4.94s
# 878:	learn: 64840.2959075	total: 35.3s	remaining: 4.87s
# 880:	learn: 64818.9391076	total: 35.4s	remaining: 4.78s
# 882:	learn: 64805.8857132	total: 35.5s	remaining: 4.7s
# 884:	learn: 64769.3581529	total: 35.6s	remaining: 4.62s
# 886:	learn: 64758.3217889	total: 35.7s	remaining: 4.54s
# 888:	learn: 64705.6818072	total: 35.7s	remaining: 4.46s
# 890:	learn: 64681.7622302	total: 35.8s	remaining: 4.38s
# 892:	learn: 64640.9753087	total: 35.9s	remaining: 4.3s
# 894:	learn: 64637.5833319	total: 36s	remaining: 4.22s
# 896:	learn: 64602.0329215	total: 36.1s	remaining: 4.14s
# 898:	learn: 64583.2116215	total: 36.2s	remaining: 4.06s
# 900:	learn: 64564.4381457	total: 36.2s	remaining: 3.98s
# 902:	learn: 64510.2175864	total: 36.3s	remaining: 3.9s
# 904:	learn: 64500.4801093	total: 36.4s	remaining: 3.82s
# 906:	learn: 64480.6613928	total: 36.5s	remaining: 3.74s
# 908:	learn: 64470.5599740	total: 36.6s	remaining: 3.66s
# 910:	learn: 64453.9830181	total: 36.6s	remaining: 3.58s
# 912:	learn: 64427.5027109	total: 36.7s	remaining: 3.5s
# 914:	learn: 64416.8225315	total: 36.8s	remaining: 3.42s
# 916:	learn: 64382.2868843	total: 36.9s	remaining: 3.34s
# 918:	learn: 64362.9795495	total: 36.9s	remaining: 3.26s
# 920:	learn: 64355.5223336	total: 37s	remaining: 3.17s
# 922:	learn: 64340.0836290	total: 37.1s	remaining: 3.1s
# 924:	learn: 64312.9162030	total: 37.2s	remaining: 3.02s
# 926:	learn: 64298.5610244	total: 37.3s	remaining: 2.94s
# 928:	learn: 64271.9560653	total: 37.4s	remaining: 2.85s
# 930:	learn: 64265.7251408	total: 37.4s	remaining: 2.77s
# 932:	learn: 64249.5627543	total: 37.5s	remaining: 2.69s
# 934:	learn: 64238.2078788	total: 37.6s	remaining: 2.62s
# 936:	learn: 64218.6541223	total: 37.7s	remaining: 2.53s
# 938:	learn: 64204.3596799	total: 37.8s	remaining: 2.45s
# 940:	learn: 64196.3877335	total: 37.9s	remaining: 2.37s
# 942:	learn: 64151.9666491	total: 37.9s	remaining: 2.29s
# 944:	learn: 64117.7822559	total: 38s	remaining: 2.21s
# 946:	learn: 64102.3140446	total: 38.1s	remaining: 2.13s
# 948:	learn: 64096.7079698	total: 38.2s	remaining: 2.05s
# 950:	learn: 64043.3899458	total: 38.3s	remaining: 1.97s
# 952:	learn: 64033.5838976	total: 38.4s	remaining: 1.89s
# 954:	learn: 64007.7850555	total: 38.5s	remaining: 1.81s
# 956:	learn: 63982.5049557	total: 38.5s	remaining: 1.73s
# 958:	learn: 63962.2249565	total: 38.6s	remaining: 1.65s
# 960:	learn: 63939.8752853	total: 38.7s	remaining: 1.57s
# 962:	learn: 63926.7406121	total: 38.8s	remaining: 1.49s
# 964:	learn: 63915.1017866	total: 38.9s	remaining: 1.41s
# 966:	learn: 63894.9686954	total: 38.9s	remaining: 1.33s
# 968:	learn: 63874.1765970	total: 39s	remaining: 1.25s
# 970:	learn: 63864.1257137	total: 39.1s	remaining: 1.17s
# 972:	learn: 63821.9073925	total: 39.2s	remaining: 1.09s
# 974:	learn: 63773.8833425	total: 39.3s	remaining: 1.01s
# 976:	learn: 63761.6729993	total: 39.4s	remaining: 927ms
# 978:	learn: 63747.8569565	total: 39.5s	remaining: 847ms
# 980:	learn: 63710.3287296	total: 39.6s	remaining: 767ms
# 982:	learn: 63700.0797935	total: 39.7s	remaining: 687ms
# 984:	learn: 63688.6839208	total: 39.8s	remaining: 606ms
# 986:	learn: 63671.7185382	total: 39.9s	remaining: 526ms
# 988:	learn: 63647.6699002	total: 40s	remaining: 445ms
# 990:	learn: 63639.5544006	total: 40.1s	remaining: 364ms
# 992:	learn: 63627.6813481	total: 40.2s	remaining: 283ms
# 994:	learn: 63622.4119078	total: 40.3s	remaining: 202ms
# 996:	learn: 63607.9919713	total: 40.4s	remaining: 121ms
# 998:	learn: 63584.4858641	total: 40.4s	remaining: 40.5ms
# 999:	learn: 63574.7453982	total: 40.5s	remaining: 0us

# %%
# Predict on test set
scores = evaluate_model(cb_model, pool_test, y_test)
scores
# Out:
# {'mape': 0.11202561169983177, 'mae': 81904.20719290896}

# %%
import optuna
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_squared_error
from sklearn.model_selection import KFold
from optuna.integration import CatBoostPruningCallback
from sklearn.model_selection import cross_validate

def objective(trial, pool_train):
	param_grid = {
	"loss_function": "MAE",
	"n_estimators": trial.suggest_categorical("n_estimators", [500, 1000, 2000]),
	"learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
	"depth": trial.suggest_categorical("depth", [5,7,9,11,13,15,17]),
	"colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.1, 1),
	"l2_leaf_reg": trial.suggest_float('l2_leaf_reg', 1e-3, 10.0, log=True),
	"boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
	"bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
	"random_seed": 42,
	"eval_metric": "MAE",
	}

	if param_grid["bootstrap_type"] == "Bayesian":
		param_grid["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
	elif param["bootstrap_type"] == "Bernoulli":
		param_grid["subsample"] = trial.suggest_float("subsample", 0.1, 1)
	
	scores = catboost.cv(
		pool_train,
		param_grid,
		fold_count=5,
		early_stopping_rounds=100,
		verbose=0,
	)

	return scores['test-MAE-mean'].min()

# %%
from catboost import Pool, cv

cv_data = X_train_cat.copy()

labels = y_train_cat.copy()

cat_features = cat_categorical_cols.tolist()

cv_dataset = Pool(data=cv_data,
                  label=labels,
                  cat_features=cat_features)

params = {"iterations": 1000,
          "depth": 2,
          "loss_function": "MAE",
          "verbose": False}

scores = cv(cv_dataset,
            params,
            fold_count=2,
            early_stopping_rounds=100
            )
# Get the score for the best iteration
best_score = np.min(scores['test-MAE-mean'])

# %% [markdown]
# ## LightGBM

# %%
lgb_model = lightgbm.LGBMRegressor(
	learning_rate = 0.08363996779482333,
	num_leaves = 26,
	max_depth = 7,
	min_child_samples = 14,
	subsample = 0.8130687216963774,
	colsample_bytree = 0.726149859230546,
	reg_alpha = 6.495685321153756,
	reg_lambda = 0.004206014748968054,
	n_estimators = 1000,
	metric = 'mape',
	importance_type = 'gain',
	boosting_type = 'gbdt',
	verbose = 1,
	min_split_gain = 0.0,
	random_state=42,
	n_jobs=-1
)

# %%
lgb_pipe_1 = get_pipeline(lgb_model, preprocessor1)
# Train the pipeline
lgb_pipe_1.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012350 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6260
# [LightGBM] [Info] Number of data points in the train set: 26360, number of used features: 1366
# [LightGBM] [Info] Start training from score 781376.551252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   Index(['myear', 'km_driven', 'ip', 'Displacement', 'No of Cylinder',
#        'Valves per Cylinder', 'Width', 'Wheel Base', 'Front Tread',
#        'Kerb Weight', 'Seats', 'Turning Radius', 'Top Speed', 'Acceleration',
#        'Doors', 'mileage_new', 'Alloy Wheel Size', 'Max Power Delivered',
#        '...
#        'state', 'owner_type', 'Fuel Suppy System'],
#       dtype='object'))])),
#                 ('model',
#                  LGBMRegressor(colsample_bytree=0.726149859230546,
#                                importance_type='gain',
#                                learning_rate=0.08363996779482333, max_depth=7,
#                                metric='mape', min_child_samples=14,
#                                n_estimators=1000, num_leaves=26,
#                                random_state=42, reg_alpha=6.495685321153756,
#                                reg_lambda=0.004206014748968054,
#                                subsample=0.8130687216963774, verbose=1))])

# %%
scores = evaluate_model(lgb_pipe_1, X_test, y_test)
scores
# Out:
# {'mape': 0.11767337448199067, 'mae': 80567.89290751299}

# %% [markdown]
# ## XGBoost

# %%
xgb_model = xgboost.XGBRegressor(
	objective = 'reg:absoluteerror',
	learning_rate = 0.08363996779482333,
	max_depth = 7,
	min_child_samples = 14,
	subsample = 0.8130687216963774,
	colsample_bytree = 0.726149859230546,
	reg_alpha = 6.495685321153756,
	reg_lambda = 0.004206014748968054,
	n_estimators = 1000,
	importance_type = 'gain',
	verbose = 1,
	min_split_gain = 0.0,
	random_state=42,
	tree_method = "hist",
	single_precision_histogram=True,
	n_jobs=-1
)

# %%
xgb_pipe_1 = get_pipeline(xgb_model, preprocessor1)
# Train the pipeline
xgb_pipe_1.fit(X_train, y_train)
# Out:
# [20:16:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_child_samples", "min_split_gain", "single_precision_histogram", "verbose" } are not used.
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   Index(['myear', 'km_driven', 'ip', 'Displacement', 'No of Cylinder',
#        'Valves per Cylinder', 'Width', 'Wheel Base', 'Front Tread',
#        'Kerb Weight', 'Seats', 'Turning Radius', 'Top Speed', 'Acceleration',
#        'Doors', 'mileage_new', 'Alloy Wheel Size', 'Max Power Delivered',
#        '...
#                               grow_policy=None, importance_type='gain',
#                               interaction_constraints=None,
#                               learning_rate=0.08363996779482333, max_bin=None,
#                               max_cat_threshold=None, max_cat_to_onehot=None,
#                               max_delta_step=None, max_depth=7, max_leaves=None,
#                               min_child_samples=14, min_child_weight=None,
#                               min_split_gain=0.0, missing=nan,
#                               monotone_constraints=None, n_estimators=1000,
#                               n_jobs=-1, num_parallel_tree=None, ...))])

# %%
scores = evaluate_model(xgb_pipe_1, X_test, y_test)
scores
# Out:
# {'mape': 0.19746590157611224, 'mae': 132037.78464419863}

# %% [markdown]
# ## Random Forest

# %%
extra_tree_model = ExtraTreesRegressor(
	n_estimators = 300,
	max_depth = 7,
	min_samples_split = 14,
	min_samples_leaf = 1,
	bootstrap = True,
	oob_score = True,
	random_state=42,
	n_jobs=-1,
	verbose=1
)

# %%
extra_tree_pipe_1 = get_pipeline(extra_tree_model, preprocessor3)
# Train the pipeline
extra_tree_pipe_1.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  7.5min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [97], in <cell line: 3>()
#       1 extra_tree_pipe_1 = get_pipeline(extra_tree_model, preprocessor3)
#       2 # Train the pipeline
# ----> 3 extra_tree_pipe_1.fit(X_train, y_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
# --> 473 trees = Parallel(
#     474     n_jobs=self.n_jobs,
#     475     verbose=self.verbose,
#     476     prefer="threads",
#     477 )(
#     478     delayed(_parallel_build_trees)(
#     479         t,
#     480         self.bootstrap,
#     481         X,
#     482         y,
#     483         sample_weight,
#     484         i,
#     485         len(trees),
#     486         verbose=self.verbose,
#     487         class_weight=self.class_weight,
#     488         n_samples_bootstrap=n_samples_bootstrap,
#     489     )
#     490     for i, t in enumerate(trees)
#     491 )
#     493 # Collect newly grown trees
#     494 self.estimators_.extend(trees)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
scores = evaluate_model(extra_tree_pipe_1, X_test, y_test)
scores

# %% [markdown]
# ## Linear Regression
